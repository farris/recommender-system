# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import re

# %%
def compiler(file_list):
    
    MAP = []
    alpha = []
    reg = []
    rank = [] 
    p = re.compile('-?\ *[0-9]+\.?[0-9]*(?:[Ee]\ *-?\ *[0-9]+)?') 

    for file in file_list:
        print(file)
        with open(file) as fp:
            for line in (fp):
                if 'MAP' in line:
                   #print(line)

                    MAP.append(float(p.findall(line)[0]))

                if 'alpha' in line:

                    alpha.append(float(p.findall(line)[0]))


                if 'regParam' in line:

                    reg.append(float(p.findall(line)[0]))


                if 'rank' in line:

                    rank.append(float(p.findall(line)[0]))

    return  MAP, alpha, reg, rank

# %%
MAP, alpha, reg, rank = compiler(['GS500.txt'])
# Out:
# GS500.txt

# %%
len(MAP)
# Out:
# 48

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
cmap_reversed = plt.cm.get_cmap('binary')

fig = plt.figure(figsize=(35,25))

ax = fig.add_subplot(111, projection='3d')

y = np.asarray(alpha)
x = np.asarray(reg)
z = np.asarray(rank)
c = np.asarray(MAP)

img = ax.scatter(x, y, z, c=c, cmap=cmap_reversed ,s = 1000)
fig.colorbar(img)
ax.set_ylabel('alpha',fontsize = 30);
ax.set_xlabel('reg',fontsize = 30);
ax.set_zlabel('rank',fontsize = 30);
ax.xaxis.set_tick_params(labelsize=25)
ax.yaxis.set_tick_params(labelsize=25)
ax.zaxis.set_tick_params(labelsize=25)

# %%
idx = np.argmax(MAP)

# %%
rank[idx]
# Out:
# 125.0

# %%
alpha[idx]
# Out:
# 10.0

# %%
reg[idx]
# Out:
# 1.0

# %%
np.max(MAP)
# Out:
# 0.008021891057642562

# %%
all = list(zip(alpha, reg,rank,MAP))
all.sort(reverse=True, key=lambda x:x[3])
all
# Out:
# [(10.0, 1.0, 125.0, 0.008021891057642562),
#  (10.0, 0.1, 125.0, 0.007838916942776945),
#  (10.0, 1.0, 100.0, 0.007681166364014973),
#  (10.0, 0.1, 100.0, 0.0074970668183988705),
#  (10.0, 5.0, 125.0, 0.007353818871901163),
#  (10.0, 5.0, 100.0, 0.007054224650518552),
#  (2.0, 1.0, 125.0, 0.006925617674194321),
#  (10.0, 1.0, 50.0, 0.006642718744849414),
#  (2.0, 1.0, 100.0, 0.0066168882823139435),
#  (2.0, 0.1, 125.0, 0.006550302538825899),
#  (10.0, 0.1, 50.0, 0.006543383866208409),
#  (0.1, 0.1, 125.0, 0.0063941538102401715),
#  (2.0, 0.1, 100.0, 0.006333562318197095),
#  (1.0, 0.1, 125.0, 0.006192151784250076),
#  (0.1, 0.1, 100.0, 0.006142741001879249),
#  (10.0, 5.0, 50.0, 0.0061388616339484265),
#  (1.0, 0.1, 100.0, 0.005974774968343113),
#  (1.0, 1.0, 125.0, 0.005832171867759286),
#  (2.0, 1.0, 50.0, 0.005731707355330744),
#  (2.0, 0.1, 50.0, 0.005650330263142334),
#  (0.1, 0.1, 50.0, 0.005559885114392003),
#  (1.0, 1.0, 100.0, 0.0055420006342730655),
#  (1.0, 0.1, 50.0, 0.005354523746142504),
#  (1.0, 1.0, 50.0, 0.004784721756206115),
#  (10.0, 1.0, 10.0, 0.004583756986730438),
#  (10.0, 0.1, 10.0, 0.0045671907113601674),
#  (10.0, 5.0, 10.0, 0.00424257211080175),
#  (2.0, 0.1, 10.0, 0.004122491625895373),
#  (0.1, 0.1, 10.0, 0.004045113366658331),
#  (1.0, 0.1, 10.0, 0.003981712708905778),
#  (2.0, 1.0, 10.0, 0.003952217088597765),
#  (1.0, 1.0, 10.0, 0.003467814830503567),
#  (2.0, 5.0, 125.0, 0.002092103987572119),
#  (2.0, 5.0, 100.0, 0.0020352263394076563),
#  (2.0, 5.0, 50.0, 0.0019160894782962491),
#  (2.0, 5.0, 10.0, 0.001051775855137582),
#  (0.1, 1.0, 125.0, 6.371739660723483e-05),
#  (1.0, 5.0, 125.0, 3.831602427754131e-05),
#  (1.0, 5.0, 100.0, 3.777736084059618e-05),
#  (0.1, 1.0, 100.0, 3.4832484887943384e-05),
#  (1.0, 5.0, 50.0, 2.891137405424747e-05),
#  (0.1, 5.0, 50.0, 2.4829407817843208e-05),
#  (0.1, 5.0, 10.0, 2.4244345394120806e-05),
#  (0.1, 5.0, 125.0, 2.4174331603296653e-05),
#  (0.1, 5.0, 100.0, 2.2191720588955135e-05),
#  (0.1, 1.0, 50.0, 2.1372471065709014e-05),
#  (1.0, 5.0, 10.0, 1.6336551418003426e-05),
#  (0.1, 1.0, 10.0, 1.4413974272103903e-05)]

# %%
# !git add -A
# !git commit -m “edit”
# !git push origin FA-Edits
# Out:
# On branch FA-Edits
# nothing to commit, working tree clean
# Everything up-to-date
