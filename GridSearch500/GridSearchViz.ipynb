# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import re

# %%
def compiler(file_list):
    
    MAP = []
    alpha = []
    reg = []
    rank = [] 
    p = re.compile('-?\ *[0-9]+\.?[0-9]*(?:[Ee]\ *-?\ *[0-9]+)?') 

    for file in file_list:
        print(file)
        with open(file) as fp:
            for line in (fp):
                if 'MAP' in line:
                   #print(line)

                    MAP.append(float(p.findall(line)[0]))

                if 'alpha' in line:

                    alpha.append(float(p.findall(line)[0]))


                if 'regParam' in line:

                    reg.append(float(p.findall(line)[0]))


                if 'rank' in line:

                    rank.append(float(p.findall(line)[0]))

    return  MAP, alpha, reg, rank

# %%
MAP, alpha, reg, rank = compiler(['GS501.txt'])
# Out:
# GS501.txt

# %%
len(MAP)
# Out:
# 30

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
cmap_reversed = plt.cm.get_cmap('binary')

fig = plt.figure(figsize=(20,15))

ax = fig.add_subplot(111, projection='3d')

y = np.asarray(alpha)
x = np.asarray(reg)
z = np.asarray(rank)
c = np.asarray(MAP)

img = ax.scatter(x, y, z, c=c, cmap=cmap_reversed ,s = 1000)
fig.colorbar(img)
ax.set_ylabel('alpha',fontsize = 30);
ax.set_xlabel('reg',fontsize = 30);
ax.set_zlabel('rank',fontsize = 30);
ax.xaxis.set_tick_params(labelsize=25)
ax.yaxis.set_tick_params(labelsize=25)
ax.zaxis.set_tick_params(labelsize=25)

# %%
idx = np.argmax(MAP)

# %%
rank[idx]
# Out:
# 50.0

# %%
alpha[idx]
# Out:
# 100.0

# %%
reg[idx]
# Out:
# 5.0

# %%
np.max(MAP)
# Out:
# 0.007397582921548863

# %%
all = list(zip(alpha, reg,rank,MAP))
all.sort(reverse=True, key=lambda x:x[3])
all
# Out:
# [(100.0, 5.0, 50.0, 0.007397582921548863),
#  (100.0, 0.0, 50.0, 0.007305010460494084),
#  (100.0, 10.0, 50.0, 0.00729006780855857),
#  (50.0, 5.0, 50.0, 0.0072379241964908685),
#  (50.0, 0.0, 50.0, 0.0072081890138560875),
#  (50.0, 10.0, 50.0, 0.007025620729165832),
#  (25.0, 0.0, 50.0, 0.006999141761284049),
#  (25.0, 5.0, 50.0, 0.006984325711651836),
#  (100.0, 25.0, 50.0, 0.0067633360217935305),
#  (10.0, 0.0, 50.0, 0.006626095925221415),
#  (25.0, 10.0, 50.0, 0.0064607130220018655),
#  (10.0, 5.0, 50.0, 0.006161658793263847),
#  (50.0, 25.0, 50.0, 0.005904738197036435),
#  (100.0, 50.0, 50.0, 0.00562743100764164),
#  (10.0, 10.0, 50.0, 0.004529005912014491),
#  (0.0, 0.0, 50.0, 0.0043358683034970275),
#  (25.0, 25.0, 50.0, 0.004269066709143346),
#  (50.0, 50.0, 50.0, 0.003966846285808514),
#  (100.0, 100.0, 50.0, 0.003493665881040668),
#  (25.0, 50.0, 50.0, 0.0014709005042566272),
#  (50.0, 100.0, 50.0, 0.0011555569666493412),
#  (10.0, 25.0, 50.0, 0.0009754313204162917),
#  (0.0, 25.0, 50.0, 0.00012737281145763958),
#  (0.0, 10.0, 50.0, 0.00012204097860557764),
#  (0.0, 5.0, 50.0, 0.00012191633046773074),
#  (0.0, 50.0, 50.0, 8.297007514095127e-05),
#  (25.0, 100.0, 50.0, 6.736291796337244e-05),
#  (10.0, 50.0, 50.0, 2.2595303300359335e-05),
#  (10.0, 100.0, 50.0, 1.7160550467687805e-05),
#  (0.0, 100.0, 50.0, 6.685375708175782e-06)]

# %%
# !git add -A
# !git commit -m “edit”
# !git push origin FA-Edits
# Out:
# [FA-Edits f2d951a] “edit”
#  1 file changed, 289 insertions(+), 375 deletions(-)
#  rewrite GridSearch500/GridSearchViz.ipynb (95%)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 149.82 KiB | 2.27 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To github.com:nyu-big-data/final-project-team7.git
#    640138c..f2d951a  FA-Edits -> FA-Edits
