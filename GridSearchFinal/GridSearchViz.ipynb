# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import re

# %%
def compiler(file_list):
    
    MAP = []
    alpha = []
    reg = []
    rank = [] 
    p = re.compile('-?\ *[0-9]+\.?[0-9]*(?:[Ee]\ *-?\ *[0-9]+)?') 

    for file in file_list:
        print(file)
        with open(file) as fp:
            for line in (fp):
                if 'MAP' in line:
                   #print(line)

                    MAP.append(float(p.findall(line)[0]))

                if 'alpha' in line:

                    alpha.append(float(p.findall(line)[0]))


                if 'regParam' in line:

                    reg.append(float(p.findall(line)[0]))


                if 'rank' in line:

                    rank.append(float(p.findall(line)[0]))

    return  MAP, alpha, reg, rank

# %%
MAP, alpha, reg, rank = compiler(['GS503.txt'])
# Out:
# GS503.txt

# %%
len(MAP)
# Out:
# 50

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
cmap_reversed = plt.cm.get_cmap('binary')

fig = plt.figure(figsize=(35,25))

ax = fig.add_subplot(111, projection='3d')

y = np.asarray(alpha)
x = np.asarray(reg)
z = np.asarray(rank)
c = np.asarray(MAP)

img = ax.scatter(x, y, z, c=c, cmap=cmap_reversed ,s = 1000)
fig.colorbar(img)
ax.set_ylabel('alpha',fontsize = 30);
ax.set_xlabel('reg',fontsize = 30);
ax.set_zlabel('rank',fontsize = 30);
ax.xaxis.set_tick_params(labelsize=25)
ax.yaxis.set_tick_params(labelsize=25)
ax.zaxis.set_tick_params(labelsize=25)

# %%
idx = np.argmax(MAP)

# %%
rank[idx]
# Out:
# 100.0

# %%
alpha[idx]
# Out:
# 100.0

# %%
reg[idx]
# Out:
# 10.0

# %%
np.max(MAP)
# Out:
# 0.0643748037365078

# %%
all = list(zip(alpha, reg,rank,MAP))
all.sort(reverse=True, key=lambda x:x[3])
all
# Out:
# [(100.0, 10.0, 100.0, 0.0643748037365078),
#  (0.01, 0.1, 100.0, 0.060419617081013594),
#  (10.0, 1.0, 100.0, 0.060230514805570554),
#  (0.001, 0.1, 100.0, 0.05945632562539456),
#  (10.0, 0.1, 100.0, 0.057213847027525785),
#  (100.0, 1.0, 100.0, 0.05672502279274642),
#  (10.0, 0.01, 100.0, 0.05598307965335569),
#  (100.0, 10.0, 50.0, 0.05399147153355536),
#  (100.0, 0.1, 100.0, 0.05359412116414874),
#  (100.0, 0.01, 100.0, 0.05331084033965804),
#  (10.0, 1.0, 50.0, 0.05204447343866243),
#  (0.01, 0.1, 50.0, 0.050104776190646044),
#  (10.0, 0.1, 50.0, 0.04966104424991243),
#  (0.001, 0.1, 50.0, 0.04933025964688657),
#  (10.0, 0.01, 50.0, 0.048336719655128986),
#  (100.0, 1.0, 50.0, 0.04790846897135588),
#  (100.0, 50.0, 100.0, 0.0478397346381743),
#  (1.0, 0.1, 100.0, 0.047619922290396965),
#  (1.0, 0.01, 100.0, 0.045769635023369816),
#  (100.0, 0.1, 50.0, 0.045509401406231234),
#  (100.0, 0.01, 50.0, 0.045220598462665226),
#  (1.0, 0.1, 50.0, 0.041855460294231865),
#  (1.0, 0.01, 50.0, 0.040357894687642025),
#  (100.0, 50.0, 50.0, 0.039172986553105214),
#  (0.001, 0.01, 100.0, 0.039095227673134385),
#  (0.01, 0.01, 100.0, 0.03866612466331078),
#  (0.001, 0.01, 50.0, 0.03754072899075138),
#  (0.01, 0.01, 50.0, 0.037103053466763215),
#  (1.0, 1.0, 100.0, 0.028776595099353063),
#  (10.0, 10.0, 100.0, 0.027453273992768732),
#  (10.0, 10.0, 50.0, 0.022624203478673166),
#  (1.0, 1.0, 50.0, 0.022599971416731236),
#  (0.001, 1.0, 100.0, 0.0013685934076451862),
#  (0.01, 1.0, 100.0, 0.0009938141543588154),
#  (0.001, 50.0, 100.0, 0.0008240992718767577),
#  (0.001, 1.0, 50.0, 0.000601972025060004),
#  (0.001, 50.0, 50.0, 0.0005338643334742471),
#  (0.001, 10.0, 50.0, 0.00049297630879124),
#  (0.01, 1.0, 50.0, 0.000471531896356671),
#  (0.01, 50.0, 100.0, 0.00045098858801309886),
#  (0.001, 10.0, 100.0, 0.0004003590655849466),
#  (0.01, 50.0, 50.0, 0.0002890776738940512),
#  (0.01, 10.0, 50.0, 0.00021374694970087898),
#  (0.01, 10.0, 100.0, 0.00020325691117133505),
#  (10.0, 50.0, 100.0, 7.63751751662283e-05),
#  (1.0, 10.0, 100.0, 7.524797515945883e-05),
#  (1.0, 10.0, 50.0, 6.470332319372228e-05),
#  (1.0, 50.0, 100.0, 5.8119973944421975e-05),
#  (1.0, 50.0, 50.0, 4.824906624207046e-05),
#  (10.0, 50.0, 50.0, 4.327848542418209e-05)]

# %%
# !git add -A
# !git commit -m “edit”
# !git push origin FA-Edits
# Out:
# [FA-Edits c1f1b3b] “edit”
#  4 files changed, 911 insertions(+)
#  create mode 100644 GridSearchFinal/.DS_Store
#  create mode 100644 GridSearchFinal/GS503.txt
#  create mode 100644 GridSearchFinal/GridSearchViz.ipynb
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 254.48 KiB | 2.83 MiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:nyu-big-data/final-project-team7.git
#    d6f5969..c1f1b3b  FA-Edits -> FA-Edits
