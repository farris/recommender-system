# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
MAP = []
alpha = []
reg = []
rank = []
import re
p = re.compile('-?\ *[0-9]+\.?[0-9]*(?:[Ee]\ *-?\ *[0-9]+)?') 
with open('GS.txt') as fp:
    for line in (fp):
        if 'MAP' in line:

            MAP.append(float(p.findall(line)[0]))

        if 'alpha' in line:

            alpha.append(float(p.findall(line)[0]))


        if 'regParam' in line:

            reg.append(float(p.findall(line)[0]))


        if 'rank' in line:

            rank.append(float(p.findall(line)[0]))

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure(figsize=(20,10))

ax = fig.add_subplot(111, projection='3d')

x = alpha
y = reg
z = rank
c = MAP

img = ax.scatter(x, y, z, c=c, cmap=plt.cool())
fig.colorbar(img)
ax.set_xlabel('alpha');
ax.set_ylabel('reg');
ax.set_zlabel('rank');

# %%
rank
# Out:
# [50.0,
#  60.0,
#  5.0,
#  10.0,
#  50.0,
#  60.0,
#  5.0,
#  10.0,
#  50.0,
#  60.0,
#  5.0,
#  10.0,
#  50.0,
#  60.0,
#  5.0,
#  10.0,
#  50.0,
#  60.0,
#  5.0,
#  10.0,
#  50.0,
#  60.0,
#  5.0,
#  10.0,
#  50.0,
#  60.0,
#  5.0,
#  10.0,
#  50.0,
#  60.0]

# %%
MAP
# Out:
# [0.008672356372134853,
#  0.008927045510854265,
#  0.0020745755504341513,
#  0.0035411732521836246,
#  0.00805642669972935,
#  0.009030592213728376,
#  8.797022999860035e-05,
#  8.92835560574691e-06,
#  9.466843244474825e-06,
#  1.537019353195824e-05,
#  1.243306485181485e-05,
#  9.876587995337997e-06,
#  1.5593508550945615e-05,
#  1.8469925074925074e-05,
#  0.005700375063802927,
#  0.006471178394641319,
#  0.009413218837720843,
#  0.009991553172182798,
#  0.004843029641739353,
#  0.006022553815387313,
#  0.008888828205848364,
#  0.009513875736888442,
#  0.00019639775471137462,
#  0.00040983575848608725,
#  0.0018392225869210926,
#  0.0014889564581074635,
#  1.4737715878892354e-05,
#  1.553455760527742e-05,
#  2.0029137470799556e-05,
#  2.748256516747936e-05]
