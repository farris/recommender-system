# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import re

# %%
def compiler(file_list):
    
    MAP = []
    alpha = []
    reg = []
    rank = [] 
    p = re.compile('-?\ *[0-9]+\.?[0-9]*(?:[Ee]\ *-?\ *[0-9]+)?') 

    for file in file_list:
        print(file)
        with open(file) as fp:
            for line in (fp):
                if 'MAP' in line:
                   #print(line)

                    MAP.append(float(p.findall(line)[0]))

                if 'alpha' in line:

                    alpha.append(float(p.findall(line)[0]))


                if 'regParam' in line:

                    reg.append(float(p.findall(line)[0]))


                if 'rank' in line:

                    rank.append(float(p.findall(line)[0]))

    return  MAP, alpha, reg, rank

# %%
MAP, alpha, reg, rank = compiler(['GS1.txt','GS2.txt','GS3.txt','GS4.txt'])
# Out:
# GS1.txt
# GS2.txt
# GS3.txt
# GS4.txt

# %%
len(MAP)
# Out:
# 224

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
cmap_reversed = plt.cm.get_cmap('binary')

fig = plt.figure(figsize=(35,25))

ax = fig.add_subplot(111, projection='3d')

y = np.asarray(alpha)
x = np.asarray(reg)
z = np.asarray(rank)
c = np.asarray(MAP)

img = ax.scatter(x, y, z, c=c, cmap=cmap_reversed ,s = 1000)
fig.colorbar(img)
ax.set_ylabel('alpha',fontsize = 30);
ax.set_xlabel('reg',fontsize = 30);
ax.set_zlabel('rank',fontsize = 30);
ax.xaxis.set_tick_params(labelsize=25)
ax.yaxis.set_tick_params(labelsize=25)
ax.zaxis.set_tick_params(labelsize=25)

# %%
idx = np.argmax(MAP)

# %%
rank[idx]
# Out:
# 125.0

# %%
alpha[idx]
# Out:
# 10.0

# %%
reg[idx]
# Out:
# 1.0

# %%
np.max(MAP)
# Out:
# 0.015344432742113754

# %%
all = list(zip(alpha, reg,rank,MAP))
all.sort(reverse=True, key=lambda x:x[3])
all
# Out:
# [(10.0, 1.0, 125.0, 0.015344432742113754),
#  (10.0, 1.0, 125.0, 0.015325059701167725),
#  (10.0, 0.1, 125.0, 0.014818333297408599),
#  (10.0, 0.1, 125.0, 0.01478753918855092),
#  (5.0, 0.1, 125.0, 0.014413875834554927),
#  (5.0, 0.1, 125.0, 0.014391806287451252),
#  (10.0, 1.0, 100.0, 0.014215590996518422),
#  (10.0, 1.0, 100.0, 0.014189255477482789),
#  (5.0, 1.0, 125.0, 0.014035068764837884),
#  (5.0, 1.0, 125.0, 0.014010527442024868),
#  (3.0, 0.1, 125.0, 0.013840541979430781),
#  (3.0, 0.1, 125.0, 0.013815307991039012),
#  (10.0, 0.1, 100.0, 0.013788285834778296),
#  (10.0, 0.1, 100.0, 0.01370153790479532),
#  (5.0, 0.1, 100.0, 0.013429668490080248),
#  (5.0, 0.1, 100.0, 0.013406651375443975),
#  (0.01, 0.1, 125.0, 0.0130670445706269),
#  (0.01, 0.1, 125.0, 0.013051502829989724),
#  (5.0, 1.0, 100.0, 0.013014392562492311),
#  (5.0, 1.0, 100.0, 0.012936375253775823),
#  (3.0, 0.1, 100.0, 0.012857399666120652),
#  (3.0, 0.1, 100.0, 0.012835529746269175),
#  (0.01, 0.1, 100.0, 0.01214846626670176),
#  (0.001, 0.1, 5.0, 0.004635504573532189),
#  (0.1, 0.1, 10.0, 0.0035411732521836246),
#  (0.1, 0.1, 10.0, 0.0035048860110025466),
#  (0.99, 1.0, 100.0, 0.0024027958384066446),
#  (0.99, 1.0, 75.0, 0.002152630327951289),
#  (0.1, 0.1, 5.0, 0.0020745755504341513),
#  (0.1, 0.1, 5.0, 0.0020701289328414747),
#  (0.99, 1.0, 50.0, 0.0018392225869210926),
#  (0.99, 1.0, 50.0, 0.0018375936369123124),
#  (0.01, 100.0, 100.0, 0.00183475346400485),
#  (0.99, 1.0, 50.0, 0.001822957459983051),
#  (0.99, 1.0, 60.0, 0.0015008770052256472),
#  (0.99, 1.0, 60.0, 0.0014889564581074635),
#  (0.01, 100.0, 75.0, 0.0014421172214799565),
#  (0.01, 1.0, 125.0, 0.0014241522087430384),
#  (0.01, 1.0, 125.0, 0.0014127535106902172),
#  (0.001, 10.0, 60.0, 0.0012753295398257299),
#  (0.001, 10.0, 60.0, 0.0012552914918918128),
#  (0.01, 10.0, 60.0, 0.0011758687573067048),
#  (0.01, 10.0, 60.0, 0.0011567590756496934),
#  (0.001, 10.0, 50.0, 0.001120482773286988),
#  (0.001, 10.0, 50.0, 0.00111623271713446),
#  (0.01, 10.0, 50.0, 0.0010178098497688073),
#  (0.01, 10.0, 50.0, 0.0010134817874342865),
#  (0.01, 100.0, 50.0, 0.000981774113887819),
#  (0.01, 1.0, 100.0, 0.0009222842524521077),
#  (0.01, 1.0, 100.0, 0.0009117845804957787),
#  (0.01, 1.0, 100.0, 0.0009053895856975731),
#  (0.5, 1.0, 100.0, 0.0006158858654540439),
#  (0.5, 1.0, 50.0, 0.0005560813546529558),
#  (0.5, 1.0, 75.0, 0.0005434419857111902),
#  (0.01, 1.0, 75.0, 0.00047247902548716266),
#  (0.99, 1.0, 10.0, 0.00041653039493264765),
#  (0.99, 1.0, 10.0, 0.00040983575848608725),
#  (0.01, 1.0, 60.0, 0.00035677371572896937),
#  (0.01, 1.0, 60.0, 0.00035676177117410296),
#  (0.001, 1.0, 50.0, 0.000327783613223307),
#  (0.001, 1.0, 60.0, 0.00032449208326901376),
#  (0.001, 1.0, 60.0, 0.0003242222100923563),
#  (0.001, 1.0, 50.0, 0.00032190744013371243),
#  (0.01, 1.0, 50.0, 0.0003210207049398597),
#  (0.01, 1.0, 50.0, 0.00032091298248401663),
#  (0.01, 1.0, 50.0, 0.0003164666844456021),
#  (0.01, 1.0, 50.0, 0.0003130831049611293),
#  (0.01, 1.0, 50.0, 0.0003129495609160895),
#  (0.99, 1.0, 5.0, 0.00019639775471137462),
#  (0.99, 1.0, 5.0, 0.00018920889823178012),
#  (0.01, 10.0, 5.0, 0.00018833628684432856),
#  (0.001, 10.0, 5.0, 0.0001881893523433783),
#  (0.001, 10.0, 5.0, 0.000188183387292105),
#  (0.01, 10.0, 5.0, 0.00018511109218895255),
#  (0.001, 10.0, 10.0, 0.0001755778985008281),
#  (0.01, 10.0, 10.0, 0.0001649316925236109),
#  (0.001, 10.0, 10.0, 0.00016160797784874458),
#  (0.01, 10.0, 10.0, 0.000161162513713369),
#  (0.1, 1.0, 5.0, 9.113154715418697e-05),
#  (0.1, 1.0, 5.0, 8.797022999860035e-05),
#  (0.99, 10.0, 60.0, 2.748256516747936e-05),
#  (0.001, 1.0, 5.0, 2.6321083083583095e-05),
#  (0.99, 10.0, 60.0, 2.5849432861683193e-05),
#  (0.001, 1.0, 5.0, 2.3975216888374787e-05),
#  (0.99, 10.0, 5.0, 2.227704368644771e-05),
#  (0.99, 100.0, 100.0, 2.0909029829267433e-05),
#  (0.1, 10.0, 60.0, 2.084716035879829e-05),
#  (0.99, 10.0, 50.0, 2.0029137470799556e-05),
#  (0.1, 10.0, 60.0, 1.8469925074925074e-05),
#  (0.5, 100.0, 100.0, 1.83883569256653e-05),
#  (0.1, 10.0, 50.0, 1.6054517694780845e-05),
#  (0.99, 10.0, 50.0, 1.6020047890070777e-05),
#  (0.1, 10.0, 50.0, 1.5593508550945615e-05),
#  (0.99, 10.0, 10.0, 1.553455760527742e-05),
#  (0.1, 1.0, 60.0, 1.537019353195824e-05),
#  (0.1, 1.0, 60.0, 1.491310793323177e-05),
#  (0.99, 10.0, 5.0, 1.4737715878892354e-05),
#  (0.99, 10.0, 10.0, 1.4661679606083639e-05),
#  (0.99, 100.0, 50.0, 1.4041964921127017e-05),
#  (0.99, 100.0, 75.0, 1.3417926348471679e-05),
#  (0.1, 10.0, 5.0, 1.243306485181485e-05),
#  (0.01, 1.0, 5.0, 1.225616605616607e-05),
#  (0.5, 100.0, 50.0, 1.1917806254226405e-05),
#  (0.5, 100.0, 75.0, 1.1470667670476051e-05),
#  (0.01, 1.0, 5.0, 1.1308134920634915e-05),
#  (0.1, 10.0, 10.0, 1.0911565656565658e-05),
#  (0.1, 1.0, 50.0, 1.0585586532490555e-05),
#  (0.1, 10.0, 5.0, 9.892455386684926e-06),
#  (0.1, 10.0, 10.0, 9.876587995337997e-06),
#  (0.1, 1.0, 50.0, 9.466843244474825e-06),
#  (0.1, 1.0, 10.0, 8.92835560574691e-06),
#  (0.1, 1.0, 10.0, 8.426773226773225e-06),
#  (0.001, 1.0, 10.0, 6.2464285714285745e-06),
#  (0.001, 1.0, 10.0, 4.857142857142857e-06),
#  (0.01, 1.0, 10.0, 4.732142857142861e-06),
#  (0.01, 1.0, 10.0, 4.427380952380952e-06)]

# %%
# !git add -A
# !git commit -m “edit”
# !git push origin FA-Edits
# Out:
# [FA-Edits 6282234] “edit”
#  2 files changed, 649 insertions(+), 524 deletions(-)
#  create mode 100644 GS4.txt
#  rewrite GridSearchViz.ipynb (90%)
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 245.16 KiB | 2.82 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To github.com:nyu-big-data/final-project-team7.git
#    8ccd90c..6282234  FA-Edits -> FA-Edits
